# %%
import gymnasium as gym

from stable_baselines3 import A2C
# Out:
# 2023-06-27 13:58:28.000397: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-27 13:58:28.845025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
    # VecEnv resets automatically
    #if done:
    #   obs = vec_env.reset(close=True)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.5     |
# |    ep_rew_mean        | 14.5     |
# | time/                 |          |
# |    fps                | 605      |
# |    iterations         | 100      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 500      |
# | train/                |          |
# |    entropy_loss       | -0.628   |
# |    explained_variance | 0.448    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -0.716   |
# |    value_loss         | 7.48     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 14.4     |
# |    ep_rew_mean        | 14.4     |
# | time/                 |          |
# |    fps                | 596      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -0.637   |
# |    explained_variance | 0.0791   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -1.62    |
# |    value_loss         | 54       |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 16       |
# |    ep_rew_mean        | 16       |
# | time/                 |          |
# |    fps                | 612      |
# |    iterations         | 300      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -0.69    |
# |    explained_variance | 0.00433  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.7      |
# |    value_loss         | 7.12     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 17.5     |
# |    ep_rew_mean        | 17.5     |
# | time/                 |          |
# |    fps                | 604      |
# |    iterations         | 400      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -0.689   |
# |    explained_variance | 0.0254   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | 1.68     |
# |    value_loss         | 7.09     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 19.7     |
# |    ep_rew_mean        | 19.7     |
# | time/                 |          |
# |    fps                | 616      |
# |    iterations         | 500      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 2500     |
# | train/                |          |
# |    entropy_loss       | -0.673   |
# |    explained_variance | 0.215    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | 1.65     |
# |    value_loss         | 5.54     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 23.3     |
# |    ep_rew_mean        | 23.3     |
# | time/                 |          |
# |    fps                | 629      |
# |    iterations         | 600      |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -0.57    |
# |    explained_variance | 0.00151  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.86     |
# |    value_loss         | 5.46     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 26.4     |
# |    ep_rew_mean        | 26.4     |
# | time/                 |          |
# |    fps                | 635      |
# |    iterations         | 700      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -0.58    |
# |    explained_variance | 0.0281   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 1.41     |
# |    value_loss         | 4.91     |
# ------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 31.5      |
# |    ep_rew_mean        | 31.5      |
# | time/                 |           |
# |    fps                | 633       |
# |    iterations         | 800       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -0.63     |
# |    explained_variance | -2.42e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 1.24      |
# |    value_loss         | 4.31      |
# -------------------------------------
# -------------------------------------
# | rollout/              |           |
# |    ep_len_mean        | 34.5      |
# |    ep_rew_mean        | 34.5      |
# | time/                 |           |
# |    fps                | 627       |
# |    iterations         | 900       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -0.589    |
# |    explained_variance | -0.000129 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 0.867     |
# |    value_loss         | 3.76      |
# -------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 39.1     |
# |    ep_rew_mean        | 39.1     |
# | time/                 |          |
# |    fps                | 631      |
# |    iterations         | 1000     |
# |    time_elapsed       | 7        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -0.552   |
# |    explained_variance | 0.00493  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.27     |
# |    value_loss         | 3.26     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 44       |
# |    ep_rew_mean        | 44       |
# | time/                 |          |
# |    fps                | 624      |
# |    iterations         | 1100     |
# |    time_elapsed       | 8        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -0.667   |
# |    explained_variance | 4.33e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 0.827    |
# |    value_loss         | 2.82     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 48       |
# |    ep_rew_mean        | 48       |
# | time/                 |          |
# |    fps                | 620      |
# |    iterations         | 1200     |
# |    time_elapsed       | 9        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -0.537   |
# |    explained_variance | -0.0002  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | 0.523    |
# |    value_loss         | 2.4      |
# ------------------------------------
